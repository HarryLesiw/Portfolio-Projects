# %%
# import libraries
import pandas as pd
import seaborn as sns
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn'

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline

# %%
# read in data as a data frame
df = pd.read_csv(r"C:\Users\hlesi\OneDrive - Loughborough University\Documents\Datasets\movies.csv")
df #shows a quick overview of data
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#Let us get some quick info about the dataset
#There are 7668 rows and 15 columns, we need to see if there are any missing data etc
df.info()
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# ...

# %%
#Let's just drop the null values
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5421 entries, 0 to 7652
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5421 non-null   object
#  1   rating    5421 non-null   object
#  2   genre     5421 non-null   object
#  3   year      5421 non-null   int64
#  4   released  5421 non-null   object
#  5   score     5421 non-null   float64
#  6   votes     5421 non-null   float64
#  7   director  5421 non-null   object
#  8   writer    5421 non-null   object
#  9   star      5421 non-null   object
#  10  country   5421 non-null   object
#  11  budget    5421 non-null   float64
#  12  gross     5421 non-null   float64
#  13  company   5421 non-null   object
#  14  runtime   5421 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 677.6+ KB

# %%
# Now look at the data types for each column
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Change data types to integers
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
# We're going to change the released column to just the year 
df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
df = df.drop(columns = 'year') # deleting the year as it gave a few wrong  
df = df.sort_values(by = 'gross', ascending = False) #sort by grossing w/ highest first
df
# Out:
#                                             name     rating   genre  \
# 5445                                      Avatar      PG-13  Action
# 7445                           Avengers: Endgame      PG-13  Action
# 3045                                     Titanic      PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action
# 7244                      Avengers: Infinity War      PG-13  Action
# ...                                          ...        ...     ...
# 5640                                 Tanner Hall          R   Drama
# 2434                  Philadelphia Experiment II      PG-13  Action
# 3681                                Ginger Snaps  Not Rated   Drama
# 272                                     Parasite          R  Horror
# 3203                                  Trojan War      PG-13  Comedy
#
#                                released  score      votes  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0
# ...

# %%
# Drop any duplicates
df.drop_duplicates()
# Out:
#                                             name     rating   genre  \
# 5445                                      Avatar      PG-13  Action
# 7445                           Avengers: Endgame      PG-13  Action
# 3045                                     Titanic      PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action
# 7244                      Avengers: Infinity War      PG-13  Action
# ...                                          ...        ...     ...
# 5640                                 Tanner Hall          R   Drama
# 2434                  Philadelphia Experiment II      PG-13  Action
# 3681                                Ginger Snaps  Not Rated   Drama
# 272                                     Parasite          R  Horror
# 3203                                  Trojan War      PG-13  Comedy
#
#                                released  score      votes  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0
# ...

# %%
# Budget high correlation with revenue
# Company high correlation with revenue

# %%
#Scatter plot with budget vs revenue
plt.scatter(x = df['budget'], y = df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget')
plt.ylabel('Gross Earnings')
plt.show()

# %%
# plot budget vs gross using seaborn

sns.regplot(x = 'budget', y = 'gross', data = df, scatter_kws = {'color': 'red'}, line_kws = {'color': 'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
#Look at correlation
df.corr(numeric_only = True)
# Out:
#                 score     votes    budget     gross   runtime  yearcorrect
# score        1.000000  0.474256  0.072001  0.222556  0.414068     0.061923
# votes        0.474256  1.000000  0.439675  0.614751  0.352303     0.203098
# budget       0.072001  0.439675  1.000000  0.740247  0.318695     0.320312
# gross        0.222556  0.614751  0.740247  1.000000  0.275796     0.268721
# runtime      0.414068  0.352303  0.318695  0.275796  1.000000     0.075294
# yearcorrect  0.061923  0.203098  0.320312  0.268721  0.075294     1.000000

# %%
correlation_matrix = df.corr(numeric_only = True)

sns.heatmap(data = correlation_matrix, annot = True)

plt.title('Correlation Matrix for Movie Aspects')
plt.xlabel('Movie Aspects')
plt.ylabel('Movie Aspects')
plt.show()

# %%
#let us assign a number to of the entries in the columns
df_enumerate = df
for col_name in df_enumerate.columns:
    if df_enumerate[col_name].dtype == 'object':
        df_enumerate[col_name] = df_enumerate[col_name].astype('category')
        df_enumerate[col_name] = df_enumerate[col_name].cat.codes

df_enumerate
# Out:
#       name  rating  genre  released  score      votes  director  writer  star  \
# 5445   386       5      0       527    7.8  1100000.0       785    1263  1534
# 7445   388       5      0       137    8.4   903000.0       105     513  1470
# 3045  4909       5      6       534    7.8  1100000.0       785    1263  1073
# 6663  3643       5      0       529    7.8   876000.0       768    1806   356
# 7244   389       5      0       145    8.4   897000.0       105     513  1470
# ...    ...     ...    ...       ...    ...        ...       ...     ...   ...
# 5640  3794       6      6       890    5.8     3500.0       585    2924  1498
# 2434  2969       5      0      1467    4.5     1900.0      1805    3102   186
# 3681  1595       3      6      1721    6.8    43000.0       952    1683   527
# 272   2909       6      9      1525    3.9     2300.0       261      55  1473
# 3203  4966       5      4      2152    5.7     5800.0       651     161  1811
#
# ...

# %%
df
# Out:
#                                             name     rating   genre  \
# 5445                                      Avatar      PG-13  Action
# 7445                           Avengers: Endgame      PG-13  Action
# 3045                                     Titanic      PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action
# 7244                      Avengers: Infinity War      PG-13  Action
# ...                                          ...        ...     ...
# 5640                                 Tanner Hall          R   Drama
# 2434                  Philadelphia Experiment II      PG-13  Action
# 3681                                Ginger Snaps  Not Rated   Drama
# 272                                     Parasite          R  Horror
# 3203                                  Trojan War      PG-13  Comedy
#
#                                released  score      votes  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0
# ...

# %%
correlation_matrix = df_enumerate.corr(numeric_only = True)

sns.heatmap(data = correlation_matrix, annot = True)

plt.title('Correlation Matrix for Movie Aspects')
plt.xlabel('Movie Aspects')
plt.ylabel('Movie Aspects')
plt.rcParams['figure.figsize'] = (30,10)
plt.show()

# %%
df_enumerate.corr()
# Out:
#                  name    rating     genre  released     score     votes  \
# name         1.000000 -0.029234  0.010996 -0.006152  0.014450  0.012615
# rating      -0.029234  1.000000  0.147796  0.018083  0.065983  0.006031
# genre        0.010996  0.147796  1.000000  0.022142  0.035106 -0.135990
# released    -0.006152  0.018083  0.022142  1.000000  0.045874  0.028833
# score        0.014450  0.065983  0.035106  0.045874  1.000000  0.474256
# votes        0.012615  0.006031 -0.135990  0.028833  0.474256  1.000000
# director     0.015246  0.014656 -0.008553  0.002308  0.005413 -0.010376
# writer       0.012880 -0.003149  0.017578  0.008072  0.012843 -0.005316
# star        -0.006882  0.009196  0.003341  0.015706  0.007296 -0.017638
# country     -0.025490  0.008230 -0.009164 -0.017228 -0.043051  0.041551
# budget       0.023392 -0.203946 -0.368523  0.019952  0.072001  0.439675
# gross        0.005639 -0.181906 -0.244101  0.008501  0.222556  0.614751
# ...

# %%
correlation_matrix2 = df_enumerate.corr()
corr_pairs = correlation_matrix2.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              released      -0.006152
#              score          0.014450
#                               ...
# yearcorrect  budget         0.320312
#              gross          0.268721
#              company       -0.018806
#              runtime        0.075294
#              yearcorrect    1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# budget       genre         -0.368523
# genre        budget        -0.368523
#              gross         -0.244101
# gross        genre         -0.244101
# rating       budget        -0.203946
#                               ...
# released     released       1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 225, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# votes        gross          0.614751
# gross        votes          0.614751
# budget       gross          0.740247
# gross        budget         0.740247
# name         name           1.000000
# writer       writer         1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
#Votes and budget had the highest correlation to gross earnings
